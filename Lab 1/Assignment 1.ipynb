# %%
# !pip install -q lucid>=0.2.3

# %%
import numpy as np

import ctypes.util
from lucid.misc.gl.glcontext import create_opengl_context

# Now it's safe to import OpenGL and EGL functions
import OpenGL.GL as gl
from OpenGL.GLU import *

# create_opengl_context() creates GL context that is attached to an
# offscreen surface of specified size. Note that rendering to buffers
# of different size and format is still possible with OpenGL Framebuffers.
#
# Users are expected to directly use EGL calls in case more advanced
# context management is required.
WIDTH, HEIGHT = 1000, 800
create_opengl_context((WIDTH, HEIGHT))
    
# OpenGL context is available here.

print(gl.glGetString(gl.GL_VERSION))
print(gl.glGetString(gl.GL_VENDOR)) 
#print(gl.glGetString(gl.GL_EXTENSIONS))
# Out:
# b'4.6.0 NVIDIA 510.47.03'
# b'NVIDIA Corporation'

# %%
def  addvertex(x,y):
  gl.glVertex2f(x/(WIDTH/2),y/(HEIGHT/2))

# %%
from IPython.display import display
from PIL import Image
import random #for random number
# Let's render something!
gl.glClear(gl.GL_COLOR_BUFFER_BIT)

# #Axis Drawing Code
# gl.glColor3f(255, 255, 255)
# gl.glBegin(gl.GL_LINES)
# gl.glVertex2f(0,1) #Y axix
# gl.glVertex2f(0,-1)
# gl.glVertex2f(1, 0) #X axix
# gl.glVertex2f(-1, 0)
# gl.glEnd()

gl.glPointSize(3)
gl.glBegin(gl.GL_POINTS)

for i in range(50):
  x = random.randint(-499,599)
  y = random.randint(-599,499)
  addvertex(x,y)  
  gl.glColor3f(255,255,255)

gl.glEnd()



img_buf = gl.glReadPixelsub(0, 0, WIDTH, HEIGHT, gl.GL_RGB, gl.GL_UNSIGNED_BYTE)
img = np.frombuffer(img_buf,np.uint8).reshape(HEIGHT, WIDTH, 3)[::-1]
display(Image.fromarray(img,'RGB'))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x800 at 0x7F36DE220100>

# %%
                                         #Task 2

from IPython.display import display
from PIL import Image

# Let's render something!
gl.glClear(gl.GL_COLOR_BUFFER_BIT)


#Axis Drawing Code
gl.glColor3f(0, 0, 1)
gl.glBegin(gl.GL_LINES)
gl.glVertex2f(0,1) #Y axix
gl.glVertex2f(0,-1)
gl.glVertex2f(1, 0) #X axix
gl.glVertex2f(-1, 0)
gl.glEnd()


#code of Roof
gl.glColor3f(52/255, 235/255, 174/255)
gl.glBegin(gl.GL_TRIANGLES)
addvertex(-200, 0)
addvertex(200, 0)
addvertex(0, 250)
gl.glEnd()


#code of home-structure
gl.glColor3f(52/255, 235/255, 174/255)
gl.glBegin(gl.GL_LINES)
addvertex(-200, 0)
addvertex(200, 0)

addvertex(-200, -250)
addvertex(200, -250)

addvertex(-200, 0)
addvertex(-200, -250)

addvertex(200, 0)
addvertex(200, -250)
gl.glEnd()

#code of Door
gl.glColor3f(255,255,0)
gl.glBegin(gl.GL_LINES)
addvertex(-50, -250)
addvertex(50, -250)

addvertex(-50, -100)
addvertex(50, -100)

addvertex(-50, -100)
addvertex(-50, -250)

addvertex(50, -100)
addvertex(50, -250)
gl.glEnd()

#Code of Door-knob
gl.glColor3f(1, 0, 0)
gl.glPointSize(10)
gl.glBegin(gl.GL_POINTS)
addvertex(30, -170)
gl.glEnd()

#Code of Left-window
gl.glColor3f(255,255,0)
gl.glBegin(gl.GL_LINES)
addvertex(-120, -50)
addvertex(-160, -50)

addvertex(-120, -80)
addvertex(-160, -80)

addvertex(-160, -50)
addvertex(-160, -80)

addvertex(-120, -80)
addvertex(-120, -50)

gl.glEnd()

#code of right window
gl.glColor3f(255,255,0)
gl.glBegin(gl.GL_LINES)

addvertex(120, -50)
addvertex(160, -50)

addvertex(120, -80)
addvertex(160, -80)

addvertex(120, -50)
addvertex(120, -80)

addvertex(160, -50)
addvertex(160, -80)
gl.glEnd()


img_buf = gl.glReadPixelsub(0, 0, WIDTH, HEIGHT, gl.GL_RGB, gl.GL_UNSIGNED_BYTE)
img = np.frombuffer(img_buf,np.uint8).reshape(HEIGHT, WIDTH, 3)[::-1]
display(Image.fromarray(img,'RGB'))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x800 at 0x7F36C4D1ED00>

# %%
     #Task 3


from IPython.display import display
from PIL import Image

# Let's render something!
gl.glClear(gl.GL_COLOR_BUFFER_BIT)

#Axis Drawing Code
gl.glColor3f(0, 0, 1)

gl.glBegin(gl.GL_LINES)
gl.glVertex2f(0,1) #Y axix
gl.glVertex2f(0,-1)
gl.glVertex2f(1, 0) #X axix
gl.glVertex2f(-1, 0)
gl.glEnd()


#2
gl.glColor3f(1, 0, 0)
gl.glLineWidth(4)
gl.glBegin(gl.GL_LINES)

addvertex(-450, 50)
addvertex(-400, 50)
addvertex(-400, 50)
addvertex(-400, 0)
addvertex(-400, 0)
addvertex(-450, 0)
addvertex(-400, -50)
addvertex(-450, -50)
addvertex(-450, -50)
addvertex(-450, 0)
gl.glEnd()
#############################################
#0
gl.glColor3f(52/255, 235/255, 174/2559)
gl.glLineWidth(4)
gl.glBegin(gl.GL_LINES)

addvertex(-300, 50)
addvertex(-350, 50)
addvertex(-300, 50)
addvertex(-300, 0)
addvertex(-350, 50)
addvertex(-350, 0)
addvertex(-300, -50)
addvertex(-350, -50)
addvertex(-300, -50)
addvertex(-300, 0)
addvertex(-350, -50)
addvertex(-350, 0)
gl.glEnd()
##################################################
#3
gl.glColor3f(198, 120, 171)
gl.glLineWidth(4)
gl.glBegin(gl.GL_LINES)
addvertex(-200, 50)
addvertex(-250, 50)
addvertex(-200, 50)
addvertex(-200, 0)
addvertex(-200, -50)
addvertex(-250, -50)
addvertex(-200, 0)
addvertex(-250, 0)
addvertex(-200, -50)
addvertex(-200, 0)
gl.glEnd()
######################################################
# #0
gl.glColor3f(100, 100, 0)
gl.glLineWidth(4)
gl.glBegin(gl.GL_LINES)
addvertex(-100, 50)
addvertex(-150, 50)
addvertex(-100, 50)
addvertex(-100, 0)
addvertex(-150, 50)
addvertex(-150, 0)
addvertex(-100, -50)
addvertex(-150, -50)
addvertex(-100, -50)
addvertex(-100, 0)
addvertex(-150, -50)
addvertex(-150, 0)
gl.glEnd()
####################################################
#1
gl.glColor3f(2, 0.5, 2)
gl.glLineWidth(4)
gl.glBegin(gl.GL_LINES)
addvertex(-30, 50)
addvertex(-30, 0)
addvertex(-30, -50)
addvertex(-30, 0)
gl.glEnd()
##########################################################

# #0
gl.glColor3f(1, 1, 0.5)
gl.glLineWidth(4)
gl.glBegin(gl.GL_LINES)
addvertex(50, 50)
addvertex(100, 50)
addvertex(50, 50)
addvertex(50, 0)
addvertex(100, 50)
addvertex(100, 0)
addvertex(50, -50)
addvertex(100, -50)
addvertex(50, -50)
addvertex(50, 0)
addvertex(100, -50)
addvertex(100, 0)
gl.glEnd()


#################################################

#8
gl.glColor3f(1, 1, 1)
gl.glLineWidth(4)
gl.glBegin(gl.GL_LINES)

addvertex(150, 50)
addvertex(200, 50)

addvertex(150, 50)
addvertex(150, 0)

addvertex(200, 50)
addvertex(200, 0)

addvertex(150, -50)
addvertex(200, -50)

addvertex(150, 0)
addvertex(200, 0)

addvertex(150, -50)
addvertex(150, 0)

addvertex(200, -50)
addvertex(200, 0)
gl.glEnd()

##########################################################
#9
gl.glColor3f(0, 191, 255)
gl.glLineWidth(4)
gl.glBegin(gl.GL_LINES)

addvertex(250, 50)
addvertex(300, 50)

addvertex(250, 50)
addvertex(250, 0)

addvertex(300, 50)
addvertex(300, 0)

addvertex(250, -50)
addvertex(300, -50)

addvertex(250, 0)
addvertex(300, 0)

addvertex(300, -50)
addvertex(300, 0)
gl.glEnd()
img_buf = gl.glReadPixelsub(0, 0, WIDTH, HEIGHT, gl.GL_RGB, gl.GL_UNSIGNED_BYTE)
img = np.frombuffer(img_buf,np.uint8).reshape(HEIGHT, WIDTH, 3)[::-1]
display(Image.fromarray(img,'RGB'))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x800 at 0x7F36B90B5B50>
